# %%
import rpy2

# %%
rpy2.__version__
# Out:
# '2.9.4'

# %%
from rpy2.robjects import r

# %%
r("""load('Hitters.rda')""")
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7fe1e04f9848 / R:0x55a3e3e82828>
# ['Hitters']

# %%
r.data('Hitters')
# Out:
# R object with classes: ('character',) mapped to:
# <StrVector - Python:0x7fe1c0698788 / R:0x55a3e3ec8d40>
# ['Hitters']

# %%
rdf1 = r['Hitters']
rdf1
# Out:
# R object with classes: ('data.frame',) mapped to:
# <DataFrame - Python:0x7fe1c0726b08 / R:0x55a3e1f5b600>
# [IntVector, IntVector, IntVector, IntVector, ..., IntVector, IntVector, FloatVector, FactorVec...]
#   AtBat: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fe1c0708108 / R:0x55a3e3e840c0>
# [293, 315, 479, 496, ..., 492, 475, 573, 631]
#   Hits: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fe1c06a4408 / R:0x55a3e3e8d790>
# [66, 81, 130, 141, ..., 136, 126, 144, 170]
#   HmRun: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fe1c06a4908 / R:0x55a3e3e8dcd0>
# [1, 7, 18, 20, ..., 5, 3, 9, 9]
#   Runs: <class 'rpy2.robjects.vectors.IntVector'>
#   R object with classes: ('integer',) mapped to:
# <IntVector - Python:0x7fe1c06a4e08 / R:0x55a3e3e8e210>
# ...

# %%
rdf1.to_csvfile('Hitters')
# Out:
# rpy2.rinterface.NULL

# %%
import pandas as pd
df1 = pd.read_csv('Hitters', header = 'infer')
df1.head()
# Out:
#                    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  \
# -Andy Allanson       293    66      1    30   29     14      1     293     66
# -Alan Ashby          315    81      7    24   38     39     14    3449    835
# -Alvin Davis         479   130     18    66   72     76      3    1624    457
# -Andre Dawson        496   141     20    65   78     37     11    5628   1575
# -Andres Galarraga    321    87     10    39   42     30      2     396    101
#
#                    CHmRun  CRuns  CRBI  CWalks League Division  PutOuts  \
# -Andy Allanson          1     30    29      14      A        E      446
# -Alan Ashby            69    321   414     375      N        W      632
# -Alvin Davis           63    224   266     263      A        W      880
# -Andre Dawson         225    828   838     354      N        E      200
# -Andres Galarraga      12     48    46      33      N        E      805
#
#                    Assists  Errors  Salary NewLeague
# ...
